# %% [markdown]
# <a href="https://colab.research.google.com/github/Shirley020116/latia113-1/blob/main/20241017_%E6%95%B8%E6%93%9A%E5%88%86%E6%9E%90%E5%B7%A5%E5%85%B7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_parquet('B_stat_data_112.parquet')

# %%
data.head()
# Out:
#    semester_year semester grade                   mission_name  \
# 0            112    112-1  十一年級      10/12 傳奇【生涯規劃教育－職業探索】（高階）
# 1            112    112-1  十一年級  10/12 行為藝術之母【生涯規劃教育－職業探索】（高階）
# 2            112    112-1  十一年級  10/12 行為藝術之母【生涯規劃教育－職業探索】（高階）
# 3            112    112-1  十一年級      10/12 傳奇【生涯規劃教育－職業探索】（高階）
# 4            112    112-1  十一年級  10/12 行為藝術之母【生涯規劃教育－職業探索】（高階）
#
#   mission_extra_type mission_difficulty mission_field mission_type  \
# 0               一般任務                  易            文學           連續
# 1               一般任務                  中            人物           連續
# 2               一般任務                  中            人物           連續
# 3               一般任務                  易            文學           連續
# 4               一般任務                  中            人物           連續
#
#    content_indicator_correct_rate  comprehensive_indicator_correct_rate  ...  \
# 0                             NaN                                   0.5  ...
# ...

# %%
#最後三筆資料
data.tail(3)
# Out:
#        semester_year semester grade                      mission_name  \
# 67251            112    112-1   八年級     12/11 拜託離我遠一點！【生命教育－心理健康】(中階)
# 67252            112    112-1   八年級     12/11 拜託離我遠一點！【生命教育－心理健康】(中階)
# 67253            112    112-1   八年級  12/11 邊緣型人格障礙關懷手冊【生命教育－心理健康】(中階)
#
#       mission_extra_type mission_difficulty mission_field mission_type  \
# 67251               一般任務                  易          生活知識           連續
# 67252               一般任務                  易          生活知識           連續
# 67253               一般任務                  易          說明文件          非連續
#
#        content_indicator_correct_rate  comprehensive_indicator_correct_rate  \
# 67251                             NaN                              0.000000
# 67252                             NaN                              0.500000
# 67253                             NaN                              0.333333
#
#        ...  mission_is_completed  correct_rate  mission_answer_count  \
# ...

# %%
#索引
data.index
# Out:
# RangeIndex(start=0, stop=67254, step=1)

# %%
#資料欄位名稱
data.columns
# Out:
# Index(['semester_year', 'semester', 'grade', 'mission_name',
#        'mission_extra_type', 'mission_difficulty', 'mission_field',
#        'mission_type', 'content_indicator_correct_rate',
#        'comprehensive_indicator_correct_rate',
#        'explanation_indicator_correct_rate',
#        'extraction_indicator_correct_rate', 'form_indicator_correct_rate',
#        'mission_is_completed', 'correct_rate', 'mission_answer_count',
#        'answer_duration_sec', 'created_at_utc8', 'started_at_utc8',
#        'finished_at_utc8', 'mission_status', 'user_id', 'mission_id'],
#       dtype='object')

# %%
a = data.columns
#將data的columns轉換為一個series
a_series = a.to_series()
print(a_series)
#將轉換為series的資料匯出成csv檔案
a_series.to_csv('work1.csv', index = False)
# Out:
# semester_year                                                  semester_year
# semester                                                            semester
# grade                                                                  grade
# mission_name                                                    mission_name
# mission_extra_type                                        mission_extra_type
# mission_difficulty                                        mission_difficulty
# mission_field                                                  mission_field
# mission_type                                                    mission_type
# content_indicator_correct_rate                content_indicator_correct_rate
# comprehensive_indicator_correct_rate    comprehensive_indicator_correct_rate
# explanation_indicator_correct_rate        explanation_indicator_correct_rate
# extraction_indicator_correct_rate          extraction_indicator_correct_rate
# ...

# %%
#資料型態describe shows a quick statistic summary
data_summary = data.describe()
data_summary
work = data_summary.to_csv('work2.csv', index=False)

# %%
#data sort
data.sort_index(axis=1, ascending=False)
# Out:
#                     user_id     started_at_utc8  semester_year semester  \
# 0       7494041753558798733 2024-01-11 09:56:44            112    112-1
# 1       7494041753558798733 2024-01-11 09:59:47            112    112-1
# 2       5864799667198819425                 NaT            112    112-1
# 3       5864799667198819425 2023-11-07 08:19:21            112    112-1
# 4      -1855513584520149292 2023-12-05 23:20:22            112    112-1
# ...                     ...                 ...            ...      ...
# 67249  -5512273231422033081 2023-12-12 07:36:59            112    112-1
# 67250   4716226553904638447 2023-12-19 07:46:13            112    112-1
# 67251   4716226553904638447 2023-12-19 07:50:35            112    112-1
# 67252  -8836359825275869130 2023-12-19 07:49:19            112    112-1
# 67253  -8836359825275869130 2023-12-19 07:48:20            112    112-1
#
#       mission_type mission_status                      mission_name  \
# ...
